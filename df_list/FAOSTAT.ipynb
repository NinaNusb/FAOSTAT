# %%
import pandas as pd

# %%
df_pop = pd.read_csv('df_pop.csv')

# %%
df_anim = pd.read_csv('df_anim.csv')

# %%
df_veg = pd.read_csv('df_veg.csv')

# %%
#Quelle est la dimension des jeux de données ?
len(df_anim)
# Out:
# 121965

# %%
#Quelle est la dimension des jeux de données ?
len(df_pop)
# Out:
# 358

# %%
#Quelle est la dimension des jeux de données ?
len(df_veg)
# Out:
# 121965

# %%
#A quoi ressemblent les 5 premières lignes de mes jeux de données ?
df_veg.head
# Out:
# <bound method NDFrame.head of        Domain Code                 Domain  Area Code (FAO)         Area  \
# 0              FBS  Food Balances (2010-)                2  Afghanistan
# 1              FBS  Food Balances (2010-)                2  Afghanistan
# 2              FBS  Food Balances (2010-)                2  Afghanistan
# 3              FBS  Food Balances (2010-)                2  Afghanistan
# 4              FBS  Food Balances (2010-)                2  Afghanistan
# ...            ...                    ...              ...          ...
# 121960         FBS  Food Balances (2010-)              181     Zimbabwe
# 121961         FBS  Food Balances (2010-)              181     Zimbabwe
# 121962         FBS  Food Balances (2010-)              181     Zimbabwe
# 121963         FBS  Food Balances (2010-)              181     Zimbabwe
# 121964         FBS  Food Balances (2010-)              181     Zimbabwe
#
#         Element Code                                 Element  Item Code  \
# 0                645     Food supply quantity (kg/capita/yr)       2511
# 1                645     Food supply quantity (kg/capita/yr)       2511
# 2                664           Food supply (kcal/capita/day)       2511
# 3                664           Food supply (kcal/capita/day)       2511
# 4                674  Protein supply quantity (g/capita/day)       2511
# ...              ...                                     ...        ...
# 121960           664           Food supply (kcal/capita/day)       2899
# 121961           674  Protein supply quantity (g/capita/day)       2899
# 121962           674  Protein supply quantity (g/capita/day)       2899
# 121963           684      Fat supply quantity (g/capita/day)       2899
# 121964           684      Fat supply quantity (g/capita/day)       2899
#
#                       Item  Year Code  Year             Unit    Value Flag  \
# 0       Wheat and products       2018  2018               kg   160.12   Fc
# 1       Wheat and products       2019  2019               kg   161.93   Fc
# 2       Wheat and products       2018  2018  kcal/capita/day  1372.00   Fc
# 3       Wheat and products       2019  2019  kcal/capita/day  1387.00   Fc
# 4       Wheat and products       2018  2018     g/capita/day    37.00   Fc
# ...                    ...        ...   ...              ...      ...  ...
# 121960       Miscellaneous       2019  2019  kcal/capita/day     2.00   Fc
# 121961       Miscellaneous       2018  2018     g/capita/day     0.04   Fc
# 121962       Miscellaneous       2019  2019     g/capita/day     0.07   Fc
# 121963       Miscellaneous       2018  2018     g/capita/day     0.01   Fc
# 121964       Miscellaneous       2019  2019     g/capita/day     0.03   Fc
#
#        Flag Description
# 0       Calculated data
# 1       Calculated data
# 2       Calculated data
# 3       Calculated data
# 4       Calculated data
# ...                 ...
# 121960  Calculated data
# 121961  Calculated data
# 121962  Calculated data
# 121963  Calculated data
# 121964  Calculated data
#
# [121965 rows x 14 columns]>

# %%
#A quoi ressemblent les 5 premières lignes de mes jeux de données ?
df_anim.head
# Out:
# <bound method NDFrame.head of        Domain Code                 Domain  Area Code (FAO)         Area  \
# 0              FBS  Food Balances (2010-)                2  Afghanistan
# 1              FBS  Food Balances (2010-)                2  Afghanistan
# 2              FBS  Food Balances (2010-)                2  Afghanistan
# 3              FBS  Food Balances (2010-)                2  Afghanistan
# 4              FBS  Food Balances (2010-)                2  Afghanistan
# ...            ...                    ...              ...          ...
# 121960         FBS  Food Balances (2010-)              181     Zimbabwe
# 121961         FBS  Food Balances (2010-)              181     Zimbabwe
# 121962         FBS  Food Balances (2010-)              181     Zimbabwe
# 121963         FBS  Food Balances (2010-)              181     Zimbabwe
# 121964         FBS  Food Balances (2010-)              181     Zimbabwe
#
#         Element Code                                 Element  Item Code  \
# 0                645     Food supply quantity (kg/capita/yr)       2511
# 1                645     Food supply quantity (kg/capita/yr)       2511
# 2                664           Food supply (kcal/capita/day)       2511
# 3                664           Food supply (kcal/capita/day)       2511
# 4                674  Protein supply quantity (g/capita/day)       2511
# ...              ...                                     ...        ...
# 121960           664           Food supply (kcal/capita/day)       2899
# 121961           674  Protein supply quantity (g/capita/day)       2899
# 121962           674  Protein supply quantity (g/capita/day)       2899
# 121963           684      Fat supply quantity (g/capita/day)       2899
# 121964           684      Fat supply quantity (g/capita/day)       2899
#
#                       Item  Year Code  Year             Unit    Value Flag  \
# 0       Wheat and products       2018  2018               kg   160.12   Fc
# 1       Wheat and products       2019  2019               kg   161.93   Fc
# 2       Wheat and products       2018  2018  kcal/capita/day  1372.00   Fc
# 3       Wheat and products       2019  2019  kcal/capita/day  1387.00   Fc
# 4       Wheat and products       2018  2018     g/capita/day    37.00   Fc
# ...                    ...        ...   ...              ...      ...  ...
# 121960       Miscellaneous       2019  2019  kcal/capita/day     2.00   Fc
# 121961       Miscellaneous       2018  2018     g/capita/day     0.04   Fc
# 121962       Miscellaneous       2019  2019     g/capita/day     0.07   Fc
# 121963       Miscellaneous       2018  2018     g/capita/day     0.01   Fc
# 121964       Miscellaneous       2019  2019     g/capita/day     0.03   Fc
#
#        Flag Description
# 0       Calculated data
# 1       Calculated data
# 2       Calculated data
# 3       Calculated data
# 4       Calculated data
# ...                 ...
# 121960  Calculated data
# 121961  Calculated data
# 121962  Calculated data
# 121963  Calculated data
# 121964  Calculated data
#
# [121965 rows x 14 columns]>

# %%
#A quoi ressemblent les 5 premières lignes de mes jeux de données ?
df_pop.head
# Out:
# <bound method NDFrame.head of     Domain Code                 Domain  Area Code (FAO)         Area  \
# 0           FBS  Food Balances (2010-)                2  Afghanistan
# 1           FBS  Food Balances (2010-)                2  Afghanistan
# 2           FBS  Food Balances (2010-)                3      Albania
# 3           FBS  Food Balances (2010-)                3      Albania
# 4           FBS  Food Balances (2010-)                4      Algeria
# ..          ...                    ...              ...          ...
# 353         FBS  Food Balances (2010-)              249        Yemen
# 354         FBS  Food Balances (2010-)              251       Zambia
# 355         FBS  Food Balances (2010-)              251       Zambia
# 356         FBS  Food Balances (2010-)              181     Zimbabwe
# 357         FBS  Food Balances (2010-)              181     Zimbabwe
#
#      Element Code                        Element  Item Code        Item  \
# 0             511  Total Population - Both sexes       2501  Population
# 1             511  Total Population - Both sexes       2501  Population
# 2             511  Total Population - Both sexes       2501  Population
# 3             511  Total Population - Both sexes       2501  Population
# 4             511  Total Population - Both sexes       2501  Population
# ..            ...                            ...        ...         ...
# 353           511  Total Population - Both sexes       2501  Population
# 354           511  Total Population - Both sexes       2501  Population
# 355           511  Total Population - Both sexes       2501  Population
# 356           511  Total Population - Both sexes       2501  Population
# 357           511  Total Population - Both sexes       2501  Population
#
#      Year Code  Year          Unit    Value Flag   Flag Description
# 0         2018  2018  1000 persons  37172.0    *  Unofficial figure
# 1         2019  2019  1000 persons  38042.0    *  Unofficial figure
# 2         2018  2018  1000 persons   2883.0    *  Unofficial figure
# 3         2019  2019  1000 persons   2881.0    *  Unofficial figure
# 4         2018  2018  1000 persons  42228.0    *  Unofficial figure
# ..         ...   ...           ...      ...  ...                ...
# 353       2019  2019  1000 persons  29162.0    *  Unofficial figure
# 354       2018  2018  1000 persons  17352.0    *  Unofficial figure
# 355       2019  2019  1000 persons  17861.0    *  Unofficial figure
# 356       2018  2018  1000 persons  14439.0    *  Unofficial figure
# 357       2019  2019  1000 persons  14645.0    *  Unofficial figure
#
# [358 rows x 14 columns]>

# %%
#Ajouter une colonne ‘type’ qui prendra respectivement une valeur ‘animal product’ et ‘vegetal_product’
df_anim['type'] = 'animal product'

# %%
df_anim.head(5)
# Out:
#   Domain Code                 Domain  Area Code (FAO)         Area  \
# 0         FBS  Food Balances (2010-)                2  Afghanistan
# 1         FBS  Food Balances (2010-)                2  Afghanistan
# 2         FBS  Food Balances (2010-)                2  Afghanistan
# 3         FBS  Food Balances (2010-)                2  Afghanistan
# 4         FBS  Food Balances (2010-)                2  Afghanistan
#
#    Element Code                                 Element  Item Code  \
# 0           645     Food supply quantity (kg/capita/yr)       2511
# 1           645     Food supply quantity (kg/capita/yr)       2511
# 2           664           Food supply (kcal/capita/day)       2511
# 3           664           Food supply (kcal/capita/day)       2511
# 4           674  Protein supply quantity (g/capita/day)       2511
#
#                  Item  Year Code  Year             Unit    Value Flag  \
# 0  Wheat and products       2018  2018               kg   160.12   Fc
# 1  Wheat and products       2019  2019               kg   161.93   Fc
# 2  Wheat and products       2018  2018  kcal/capita/day  1372.00   Fc
# 3  Wheat and products       2019  2019  kcal/capita/day  1387.00   Fc
# 4  Wheat and products       2018  2018     g/capita/day    37.00   Fc
#
#   Flag Description            type
# 0  Calculated data  animal product
# 1  Calculated data  animal product
# 2  Calculated data  animal product
# 3  Calculated data  animal product
# 4  Calculated data  animal product

# %%
df_anim.shape
# Out:
# (121965, 15)

# %%
#Ajouter une colonne ‘type’ qui prendra respectivement une valeur ‘animal product’ et ‘vegetal_product’
df_veg['type'] = 'veg product'

# %%
df_veg.shape
# Out:
# (121965, 15)

# %%
df_veg.head(5)
# Out:
#   Domain Code                 Domain  Area Code (FAO)         Area  \
# 0         FBS  Food Balances (2010-)                2  Afghanistan
# 1         FBS  Food Balances (2010-)                2  Afghanistan
# 2         FBS  Food Balances (2010-)                2  Afghanistan
# 3         FBS  Food Balances (2010-)                2  Afghanistan
# 4         FBS  Food Balances (2010-)                2  Afghanistan
#
#    Element Code                                 Element  Item Code  \
# 0           645     Food supply quantity (kg/capita/yr)       2511
# 1           645     Food supply quantity (kg/capita/yr)       2511
# 2           664           Food supply (kcal/capita/day)       2511
# 3           664           Food supply (kcal/capita/day)       2511
# 4           674  Protein supply quantity (g/capita/day)       2511
#
#                  Item  Year Code  Year             Unit    Value Flag  \
# 0  Wheat and products       2018  2018               kg   160.12   Fc
# 1  Wheat and products       2019  2019               kg   161.93   Fc
# 2  Wheat and products       2018  2018  kcal/capita/day  1372.00   Fc
# 3  Wheat and products       2019  2019  kcal/capita/day  1387.00   Fc
# 4  Wheat and products       2018  2018     g/capita/day    37.00   Fc
#
#   Flag Description         type
# 0  Calculated data  veg product
# 1  Calculated data  veg product
# 2  Calculated data  veg product
# 3  Calculated data  veg product
# 4  Calculated data  veg product

# %%
#Regroupez les deux jeux de données en 1 et appelez ce DataFrame product
